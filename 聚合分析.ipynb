# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data/HR.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
# 14999                 NaN             0.52               2
# 15000                 NaN        999999.00               2
# 15001                0.70             0.40               2
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# ...

# %%
df = df.dropna(axis=0 ,how="any") #axis 以行为单位删除数据， how 所有都为nan 还是 任意为nan

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
# 15001                0.70             0.40               2
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# ...

# %%
df = df[df["last_evaluation"]<1][df['department']!="sale"][df["salary"]!="nme"]
# Out:
# <ipython-input-6-049a739ce2c7>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[df["last_evaluation"]<1][df['department']!="sale"][df["salary"]!="nme"]

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# ...

# %%
df.groupby("department").mean()
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# department
# IT                     0.617586         0.713797        3.814662
# RandD                  0.620286         0.705766        3.857143
# accounting             0.579380         0.708208        3.811321
# hr                     0.595138         0.703636        3.639118
# management             0.619791         0.720000        3.848631
# marketing              0.616335         0.710830        3.686833
# product_mng            0.618225         0.710910        3.800000
# sales                  0.611716         0.704070        3.766067
# support                0.616158         0.719076        3.796996
# technical              0.603390         0.713948        3.865008
#
#              average_monthly_hours  time_spend_company  Work_accident  \
# department
# IT                      201.962109            3.464580       0.134267
# RandD                   200.055844            3.353247       0.172727
# ...

# %%
#取固定列
df.loc[:,["department","satisfaction_level"]].groupby("department").mean()
# Out:
#              satisfaction_level
# department
# IT                     0.617586
# RandD                  0.620286
# accounting             0.579380
# hr                     0.595138
# management             0.619791
# marketing              0.616335
# product_mng            0.618225
# sales                  0.611716
# support                0.616158
# technical              0.603390

# %%
df.loc[:,["department","average_monthly_hours"]].groupby("department")["average_monthly_hours"].apply(lambda x : x.max() - x.min())
# Out:
# department
# IT             212
# RandD          210
# accounting     213
# hr             212
# management     210
# marketing      214
# product_mng    212
# sales          214
# support        214
# technical      213
# Name: average_monthly_hours, dtype: int64

# %%
sns.boxplot(df[''])
