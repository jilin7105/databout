# %%
import seaborn as sns 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("data/HR.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
# 14999                 NaN             0.52               2
# 15000                 NaN        999999.00               2
# 15001                0.70             0.40               2
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# 2                        272                   4              0     1
# 3                        223                   5              0     1
# 4                        159                   3              0     1
# ...                      ...                 ...            ...   ...
# 14997                    280                   4              0     1
# 14998                    158                   3              0     1
# 14999                    158                   3              0     1
# 15000                    158                   3              0     1
# 15001                    158                   2              0     1
#
#        promotion_last_5years department  salary
# 0                          0      sales     low
# 1                          0      sales  medium
# 2                          0      sales  medium
# 3                          0      sales     low
# 4                          0      sales     low
# ...                      ...        ...     ...
# 14997                      0    support     low
# 14998                      0    support     low
# 14999                      0    support     low
# 15000                      0       sale     low
# 15001                      0       sale     nme
#
# [15002 rows x 10 columns]

# %%
plt.bar(np.arange(len(df["salary"].value_counts())) ,df["salary"].value_counts() )
# Out:
# <BarContainer object of 4 artists>

# %%
plt.title("salary")
plt.xlabel("salary")
plt.ylabel("number")
plt.xticks(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts().index())
plt.bar(np.arange(len(df["salary"].value_counts())) ,df["salary"].value_counts() )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-b99bcad594bd> in <module>
#       2 plt.xlabel("salary")
#       3 plt.ylabel("number")
# ----> 4 plt.xticks(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts().index())
#       5 plt.bar(np.arange(len(df["salary"].value_counts())) ,df["salary"].value_counts() )
#
# TypeError: 'Index' object is not callable
